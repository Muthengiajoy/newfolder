# %%
import pandas as pd

print(pd.__version__)

# series in pandas 

a = [4,5,7,3]
table = pd.Series(a,index=["a","b","c","d"])
print(table)
# Out:
# 1.5.3
# a    4
# b    5
# c    7
# d    3
# dtype: int64

# %%
import pandas as pd
a = {
    "new":[4,1,3,6]
}
print(pd.DataFrame(a,index=["day1","day2","day3","day4"]))
#data = pd.DataFrame
#print(data)
# Out:
#       new
# day1    4
# day2    1
# day3    3
# day4    6

# %%
a = {
    "new":[4,1,3],
    "month":("Jan","Feb","Mar")
}
table = pd.DataFrame(a,index=["day1","day2","day3"])
print(table)
# Out:
#       new month
# day1    4   Jan
# day2    1   Feb
# day3    3   Mar

# %%
import pandas as pd
import matplotlib.pyplot as plt

#with open("data.csv") as data:
#contents = dataread()
#print(contents)

contents = pd.read_csv("data.csv")
print(contents)
contents.plot()
plt.show()
 
contents.plot(kind = "scatter", x = "Duration", y= "Pulse")
plt.show()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
